# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
vegetables = ["cucumber", "tomato", "lettuce", "asparagus",
              "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening",
           "Agrifun", "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])

# %%
fig, ax = plt.subplots()
im = ax.imshow(harvest)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
ax.set_xticks(np.arange(len(farmers)))
# Out:
# [<matplotlib.axis.XTick at 0x25eb0f80850>,
#  <matplotlib.axis.XTick at 0x25eb0f80820>,
#  <matplotlib.axis.XTick at 0x25eb0d3c370>,
#  <matplotlib.axis.XTick at 0x25eb0f33250>,
#  <matplotlib.axis.XTick at 0x25eb0f33760>,
#  <matplotlib.axis.XTick at 0x25eb0f33c70>,
#  <matplotlib.axis.XTick at 0x25eb12a41c0>]

# %%
ax.set_yticks(np.arange(len(vegetables)))
# Out:
# [<matplotlib.axis.YTick at 0x25eb0f83160>,
#  <matplotlib.axis.YTick at 0x25eb0f80d00>,
#  <matplotlib.axis.YTick at 0x25eb0d81c70>,
#  <matplotlib.axis.YTick at 0x25eb0f33dc0>,
#  <matplotlib.axis.YTick at 0x25eb0a03cd0>,
#  <matplotlib.axis.YTick at 0x25eb12ae130>,
#  <matplotlib.axis.YTick at 0x25eb12ae700>]

# %%
ax.set_xticklabels(farmers,rotation=45,rotation_mode='anchor',ha='right')
# Out:
# [Text(0, 0, 'Farmer Joe'),
#  Text(1, 0, 'Upland Bros.'),
#  Text(2, 0, 'Smith Gardening'),
#  Text(3, 0, 'Agrifun'),
#  Text(4, 0, 'Organiculture'),
#  Text(5, 0, 'BioGoods Ltd.'),
#  Text(6, 0, 'Cornylee Corp.')]

# %%
ax.set_yticklabels(vegetables)
# Out:
# [Text(0, 0, 'cucumber'),
#  Text(0, 1, 'tomato'),
#  Text(0, 2, 'lettuce'),
#  Text(0, 3, 'asparagus'),
#  Text(0, 4, 'potato'),
#  Text(0, 5, 'wheat'),
#  Text(0, 6, 'barley')]

# %%
ax.set_title('Harvest of Local Farmers', fontsize=20, color='coral')
# Out:
# Text(0.5, 1.0254879987413492, 'Harvest of Local Farmers')

# %%
for i in range(len(vegetables)):
    for j in range(len(farmers)):
        text = ax.text(j,i, harvest[i,j],ha="center",va='center',color='w')

# %%
fig.tight_layout()
plt.show()
